# %% [markdown]
# # Forge 🛠️ Google Colab Model Vault & Deployment Notebook
#
# This notebook guides you through setting up **Forge** model inference endpoints on Google Colab using **Google Drive Model Vault**.

# %%
# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# 2. Run Hardware Compatibility Audit
# !python deploy/colab/hardware_check.py

# %%
# 3. Run Model Discovery & VRAM Check
# !python deploy/colab/model_check.py

# %%
# 4. Confirm and Download Model Checkpoint to Drive Vault
# Note: Replace with confirmed quantized checkpoint repo after verifying VRAM
# !python deploy/colab/download_model.py GLM-5.2-AWQ THUDM/glm-5.2-awq

# %%
# 5. Launch vLLM Inference Server
# !python deploy/colab/start_server.py --model-path "/content/drive/MyDrive/AI Model Vault/models/GLM-5.2-AWQ" --port 8000

# %%
# 6. Health & Benchmark Check
# !python deploy/colab/health_check.py http://localhost:8000/v1
# !python deploy/colab/benchmark.py glm
